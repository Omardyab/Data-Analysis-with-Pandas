# %% [markdown]
# # Lab: Data Analysis with Pandas
# # Video game sales
#
# Omar D'yab
# 9-Augg-2021

# %%
import pandas as pd
data=pd.read_csv('./vgsales.csv')
data
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# ## 1- Which company is the most common video game publisher?

# %%
most_common_publisher=data['Publisher'].mode()
most_common_publisher

# another way
# most_common_publisher =data['Publisher'].value_counts().idxmax()
# most_common_publisher
# Out:
# 0    Electronic Arts
# dtype: object

# %% [markdown]
# ## 2-What’s the most common platform?

# %%
most_common_platform=data['Platform'].mode()
most_common_platform
# another way
# most_common =data['Platform'].value_counts().idxmax()
# most_common
# Out:
# 0    DS
# dtype: object

# %% [markdown]
# ## 3-What about the most common genre?

# %%
most_common_genre=data['Genre'].mode()
most_common_genre
# another way
# most_common =data['Genre'].value_counts().idxmax()
# most_common
# Out:
# 0    Action
# dtype: object

# %% [markdown]
# ## 4- What are the top 20 highest grossing games?

# %%
top_twenty=data[['Name','Global_Sales','Rank']].sort_values('Global_Sales',ascending=False).head(20)
top_twenty
# Out:
#                                             Name  Global_Sales  Rank
# 0                                     Wii Sports         82.74     1
# 1                              Super Mario Bros.         40.24     2
# 2                                 Mario Kart Wii         35.82     3
# 3                              Wii Sports Resort         33.00     4
# 4                       Pokemon Red/Pokemon Blue         31.37     5
# 5                                         Tetris         30.26     6
# 6                          New Super Mario Bros.         30.01     7
# 7                                       Wii Play         29.02     8
# 8                      New Super Mario Bros. Wii         28.62     9
# 9                                      Duck Hunt         28.31    10
# 10                                    Nintendogs         24.76    11
# 11                                 Mario Kart DS         23.42    12
# 12                   Pokemon Gold/Pokemon Silver         23.10    13
# ...

# %% [markdown]
# ## 5- For North American video game sales, what’s the median?

# %%
med=data['NA_Sales'].median()
med
# Out:
# 0.08

# %% [markdown]
# ## 5.1- Provide a secondary output showing ten games surrounding the median sales output assume that games with same median value are sorted in descending order

# %%
top_ten=data[data['NA_Sales'] == med].head(10)
top_ten
# Out:
#       Rank                                               Name Platform  \
# 446    447                                  Dragon Warrior IV      NES
# 497    498        World Soccer Winning Eleven 7 International      PS2
# 1617  1619                             Farming Simulator 2015       PC
# 1926  1928                          Pro Evolution Soccer 2008     X360
# 2067  2069  Winning Eleven: Pro Evolution Soccer 2007 (All...     X360
# 2373  2375                           Phantasy Star Portable 2      PSP
# 2579  2581                               The Sims 2: Castaway      PSP
# 3186  3188                                     SingStar Queen      PS2
# 3503  3505                                         Top Spin 3      PS3
# 3703  3705               Sonic & All-Stars Racing Transformed      PS3
#
#         Year         Genre                     Publisher  NA_Sales  EU_Sales  \
# 446   1990.0  Role-Playing              Enix Corporation      0.08      0.00
# ...

# %%
top_ten=data[data['NA_Sales']== med][['Name']].head(10)
top_ten
# Out:
#                                                    Name
# 446                                   Dragon Warrior IV
# 497         World Soccer Winning Eleven 7 International
# 1617                             Farming Simulator 2015
# 1926                          Pro Evolution Soccer 2008
# 2067  Winning Eleven: Pro Evolution Soccer 2007 (All...
# 2373                           Phantasy Star Portable 2
# 2579                               The Sims 2: Castaway
# 3186                                     SingStar Queen
# 3503                                         Top Spin 3
# 3703               Sonic & All-Stars Racing Transformed

# %% [markdown]
# ## 5.2- assume that games with same median value are sorted in descending order

# %%
med_desc=(data[data['NA_Sales']== med][['Name','Rank']].sort_values('Rank',ascending=False))[['Name']].head(10)
med_desc
# Out:
#                                                    Name
# 11492                      Ultimate Shooting Collection
# 11455                                        The Hidden
# 11432                              DanceDanceRevolution
# 11431  Little League World Series Baseball: Double Play
# 11403           My English Coach: Para Hispanoparlantes
# 11390      Super Robot Taisen OG Saga: Endless Frontier
# 11386                                     Sushi Academy
# 11376                         Face Racers: Photo Finish
# 11375                   Dream Day: Wedding Destinations
# 11371            Death Jr. and the Science Fair of Doom

# %% [markdown]
# ## 6- For the top-selling game of all time, how many standard deviations above/below the mean are its sales for North America?

# %%
sd=(data['NA_Sales'].head(1)-data['NA_Sales'].mean())/data['NA_Sales'].std()
sd
# Out:
# 0    50.478988
# Name: NA_Sales, dtype: float64

# %% [markdown]
# ## 7- The Nintendo Wii seems to have outdone itself with games. How does its average number of sales compare with all of the other platforms?

# %%
sales_compare=(data['Global_Sales'].mean(), data[data['Platform']=='Wii']['Global_Sales'].mean())
sales_compare
# Out:
# (0.5374406555006628, 0.6994037735849057)

# %% [markdown]
# ## 8- Come up with 3 more questions that can be answered with this data set. (answeres are also provided)

# %% [markdown]
# ## A-For EU_Sales, what’s the median?

# %%
med=data[['EU_Sales']].median()
med
# Out:
# EU_Sales    0.02
# dtype: float64

# %% [markdown]
# ## B-Which least 10 games are avaliable in GB platform at  ?

# %%
pc_platform = data[data['Platform']=='GB'].tail(10)
pc_platform
# Out:
#         Rank                                               Name Platform  \
# 9013    9015                                     Sakura Wars GB       GB
# 9052    9054                            Star Ocean: Blue Sphere       GB
# 9107    9109                       Yu-Gi-Oh! Monster Capture GB       GB
# 9800    9802                                 Harvest Moon 2 GBC       GB
# 9865    9867               Medarot 4: Kabuto / Kuwagata Version       GB
# 11799  11801                                    Mega Man Xtreme       GB
# 11816  11818                                  Mega Man Xtreme 2       GB
# 11948  11950                                   Metal Gear Solid       GB
# 12101  12103                                       Power Pro GB       GB
# 12670  12672  Teenage Mutant Ninja Turtles II: Back from the...       GB
#
#          Year         Genre                     Publisher  NA_Sales  EU_Sales  \
# 9013   2000.0     Adventure                 Media Factory       0.0       0.0
# ...

# %% [markdown]
# ## C- What is the standard deviations of Global Sales?

# %%
data['Global_Sales'].std()
# Out:
# 1.5550279355699124

# %% [markdown]
# # Tests

# %%
def test():

    def assert_equal(actual,expected):
        assert actual == expected, f"Expected {expected} but got {actual}"
        assert_equal(most_common_publisher, 'Electronic Arts')
        assert_equal(most_common_platform, 'DS')
        assert_equal(most_common_genre, 'Action')
        assert_equal(top_twenty.iloc[0].Name, 'Wii Sports')
        assert_equal(top_twenty.iloc[19].Name, 'Brain Age: Train Your Brain in Minutes a Day')
        assert_equal(med, 0.08)
        assert_equal(top_ten.iloc[0].Name,'Dragon Warrior IV')
        assert_equal(top_ten.iloc[9].Name,'Sonic & All-Stars Racing Transformed')
        
    print("Success!!!")

test()
# Out:
# Success!!!
